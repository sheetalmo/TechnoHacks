# %% [markdown]
# Task3_Technohack
#
# Name: Sheetal More
#
# Domain-Data Analytics
#
# Batch-March 2024
#
# Aim:-Create a histogram or bar chart to visualise the distribution of data in  iris dataset

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
import pandas as pd

# %%
iris=pd.read_csv("/content/Iris (1).csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(iris.isnull().sum())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %% [markdown]
# No missing values in dataset

# %%
iris['PetalWidthCm'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris['SepalWidthCm'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.hist(iris['SepalLengthCm'],bins=15,edgecolor='k',alpha=0.7)
plt.xlabel("SepalLengthCm")
plt.ylabel("Count")
plt.title(" Histo gram sepal count")
plt.show()

# %%
iris['Species'],categories=pd.factorize(iris['Species'])
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
plt.hist(iris['PetalLengthCm'],bins=15,edgecolor='k',alpha=0.7)
plt.xlabel("PetalLengthCm")
plt.ylabel("Count")
plt.title(" Histo gram petal count")
plt.show()

# %%
iris['Species'],categories=pd.factorize(iris['Species'])
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %% [markdown]
# **Bar Chart**

# %%
species_count = iris['Species'].value_counts()
plt.bar(species_count.index,species_count.values)
plt.xlabel("Species")
plt.ylabel("Count")
plt.title(" Distribution of Species")
plt.show()

# %% [markdown]
# The distribuation are equal for all 3  species.
